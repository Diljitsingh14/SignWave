# %%
from tensorflow import keras

# Load the trained model
model = keras.models.load_model('signWageM1.h5',compile=False)

# %%
import cv2
import numpy as np

# Function to preprocess the image
def preprocess_image(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Resize the image to 28x28 pixels
    resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
    # Reshape the image to match the model input shape
    reshaped = resized.reshape(1, 28, 28, 1)
    # Normalize the image
    normalized = reshaped.astype('float32') / 255
    return normalized

# Function to predict the digit
def predict_digit(image):
    preprocessed = preprocess_image(image)
    prediction = model.predict(preprocessed)
    digit = np.argmax(prediction)
    return digit

# Capture image from webcam
cap = cv2.VideoCapture(0)

while True:
    # Read the frame from the webcam
    ret, frame = cap.read()

    # Display the frame
    cv2.imshow('Webcam', frame)

    # Detect key press
    key = cv2.waitKey(1)
    if key == ord('c'):
        # Capture the frame
        captured_image = frame.copy()

        # Preprocess and predict the digit
        digit = predict_digit(captured_image)

        # Display the predicted digit
        cv2.putText(captured_image, f"Digit: {digit}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        cv2.imshow('Captured Image', captured_image)

    elif key == ord('q'):
        break

# Release the video capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
import cv2
import numpy as np

# Load the imagec
image = cv2.imread('hand.jpg')

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply image processing techniques to isolate the hand region
_, threshold = cv2.threshold(gray, 100, 255, cv2.THRESH_BINARY)
threshold = cv2.morphologyEx(threshold, cv2.MORPH_OPEN, np.ones((3, 3), dtype=np.uint8))

# Find contours in the processed image
contours, _ = cv2.findContours(threshold, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Iterate through the contours and find the contour with the largest area
max_area = 0
hand_contour = None
for contour in contours:
    area = cv2.contourArea(contour)
    if area > max_area:
        max_area = area
        hand_contour = contour

# Draw a bounding rectangle around the detected hand
if hand_contour is not None:
    x, y, w, h = cv2.boundingRect(hand_contour)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the image with the bounding rectangle
cv2.imshow('Hand Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
  
# Used to convert protobuf message to a dictionary.
from google.protobuf.json_format import MessageToDict
  
# Initializing the Model
mpHands = mp.solutions.hands
hands = mpHands.Hands(
    static_image_mode=False,
    model_complexity=1,
    min_detection_confidence=0.75,
    min_tracking_confidence=0.75,
    max_num_hands=2)
  
# Start capturing video from webcam
cap = cv2.VideoCapture(0)
  
while True:
    # Read video frame by frame
    success, img = cap.read()
  
    # Flip the image(frame)
    img = cv2.flip(img, 1)
  
    # Convert BGR image to RGB image
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  
    # Process the RGB image
    results = hands.process(imgRGB)
  
    # If hands are present in image(frame)
    if results.multi_hand_landmarks:
  
        # Both Hands are present in image(frame)
        if len(results.multi_handedness) == 2:
                # Display 'Both Hands' on the image
            cv2.putText(img, 'Both Hands', (250, 50),
                        cv2.FONT_HERSHEY_COMPLEX,
                        0.9, (0, 255, 0), 2)
  
        # If any hand present
        else:
            for i in results.multi_handedness:
                
                # Return whether it is Right or Left Hand
                label = MessageToDict(i)
                ['classification'][0]['label']
  
                if label == 'Left':
                    
                    # Display 'Left Hand' on
                    # left side of window
                    cv2.putText(img, label+' Hand',
                                (20, 50),
                                cv2.FONT_HERSHEY_COMPLEX, 
                                0.9, (0, 255, 0), 2)
  
                if label == 'Right':
                      
                    # Display 'Left Hand'
                    # on left side of window
                    cv2.putText(img, label+' Hand', (460, 50),
                                cv2.FONT_HERSHEY_COMPLEX,
                                0.9, (0, 255, 0), 2)
  
    # Display Video and when 'q'
    # is entered, destroy the window
    cv2.imshow('Image', img)
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 import mediapipe as mp
#       4 # Used to convert protobuf message to a dictionary.
#       5 from google.protobuf.json_format import MessageToDict
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
pip install mediapipe
# Out:
# Collecting mediapipeNote: you may need to restart the kernel to use updated packages.
#
#   Using cached mediapipe-0.10.0-cp310-cp310-win_amd64.whl (50.2 MB)
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.7.0.72-cp37-abi3-win_amd64.whl (44.9 MB)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from mediapipe) (22.2.0)
# Requirement already satisfied: matplotlib in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from mediapipe) (3.6.3)
# Requirement already satisfied: numpy in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from mediapipe) (1.23.5)
# Collecting sounddevice>=0.4.4
#   Using cached sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from mediapipe) (23.3.3)
# Requirement already satisfied: absl-py in c:\users\jeetc\appdata\roaming\python\python310\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: CFFI>=1.0 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from matplotlib->mediapipe) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from matplotlib->mediapipe) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from matplotlib->mediapipe) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\jeetc\miniconda3\envs\aml1114\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: opencv-contrib-python, sounddevice, mediapipe
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\jeetc\\miniconda3\\envs\\aml1114\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
